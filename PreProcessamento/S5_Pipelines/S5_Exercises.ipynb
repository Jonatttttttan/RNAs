# %%
import pandas as pd
from sklearn.compose import ColumnTransformer, make_column_selector
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import PowerTransformer, OneHotEncoder

# %%
df = pd.read_csv("C:\\Users\\Nitro\\Desktop\\Inteligencia_Artificial\\PreProcessamento_Udemy\\sample_dataset.csv").loc[:,['mean radius', 'area error', 'mean perimeter']]
df
# Out:
#      mean radius area error  mean perimeter
# 0            NaN          A          122.80
# 1          20.57          A          132.90
# 2          19.69          A          130.00
# 3          11.42          A           77.58
# 4          20.29        NaN             NaN
# ..           ...        ...             ...
# 564        21.56          A          142.00
# 565          NaN          A          131.20
# 566        16.60          A          108.30
# 567        20.60          A          140.10
# 568         7.76          A           47.92
#
# [569 rows x 3 columns]

# %%
numerical_pipeline = Pipeline([
    ('cleaner', SimpleImputer(strategy='mean')),
    ('power', PowerTransformer())
])

categorical_pipeline = Pipeline([
    ('cleaner', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(sparse_output=False))
])

transformer = ColumnTransformer([
    ('numerical', numerical_pipeline, make_column_selector(dtype_exclude='object')),
    ('categorical', categorical_pipeline, make_column_selector(dtype_include='object'))
])

# %%
transformer.fit_transform(df)
# Out:
# array([[ 0.14898925,  1.31305907,  1.        ,  0.        ,  0.        ],
#        [ 1.77124867,  1.61013246,  1.        ,  0.        ,  0.        ],
#        [ 1.59585762,  1.52800056,  1.        ,  0.        ,  0.        ],
#        ...,
#        [ 0.88394456,  0.82431697,  1.        ,  0.        ,  0.        ],
#        [ 1.77704664,  1.80409019,  1.        ,  0.        ,  0.        ],
#        [-2.82849658, -2.89045254,  1.        ,  0.        ,  0.        ]],
#       shape=(569, 5))

# %% [markdown]
# Exercise 2

# %%
transformer.set_params(numerical__cleaner__strategy='median',
                       categorical__cleaner__strategy='constant',
                       categorical__cleaner__fill_value='N')
# Out:
# ColumnTransformer(transformers=[('numerical',
#                                  Pipeline(steps=[('cleaner',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('power',
#                                                   PowerTransformer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x000002412158A450>),
#                                 ('categorical',
#                                  Pipeline(steps=[('cleaner',
#                                                   SimpleImputer(fill_value='N',
#                                                                 strategy='constant')),
#                                                  ('encoder',
#                                                   OneHotEncoder(sparse_output=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000024121588410>)])

# %%
transformer.fit_transform(df)
# Out:
# array([[-0.05595844,  1.33240917,  1.        ,  0.        ,  0.        ,
#          0.        ],
#        [ 1.77695744,  1.61842447,  1.        ,  0.        ,  0.        ,
#          0.        ],
#        [ 1.61194827,  1.53959677,  1.        ,  0.        ,  0.        ,
#          0.        ],
#        ...,
#        [ 0.93017209,  0.85656352,  1.        ,  0.        ,  0.        ,
#          0.        ],
#        [ 1.78239188,  1.80382233,  1.        ,  0.        ,  0.        ,
#          0.        ],
#        [-2.91245375, -2.95836496,  1.        ,  0.        ,  0.        ,
#          0.        ]], shape=(569, 6))
